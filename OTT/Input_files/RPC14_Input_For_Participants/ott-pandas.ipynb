# %%
import pandas as pd

# %% [markdown]
# reading the sql file ->dataframe

# %%
hotstar=pd.read_sql('SELECT * FROM Jotstar_db',con)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 hotstar=pd.read_sql('SELECT * FROM Jotstar_db',con)
#
# NameError: name 'con' is not defined
